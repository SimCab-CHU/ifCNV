# %%
def createReadsMatrix(bamPath, bedFile):

# %%
import subprocess


command = "bedtools " + "multicov " + "-bams /Users/admin/Documents/CNV/bam/trdds/*.bam " + "-bed /Users/admin/Documents/GitHub/ifCNVR/ifCNVR/inst/bedFile.bed"
print(command)

result = subprocess.run([command])
# Out:
# bedtools multicov -bams /Users/admin/Documents/CNV/bam/trdds/*.bam -bed /Users/admin/Documents/GitHub/ifCNVR/ifCNVR/inst/bedFile.bed
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-6145f264b2f3> in <module>
#       5 print(command)
#       6
# ----> 7 result = subprocess.run([command])
#
# ~/miniconda3/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     487         kwargs['stderr'] = PIPE
#     488
# --> 489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
#     491             stdout, stderr = process.communicate(input, timeout=timeout)
#
# ...
